# %% [markdown]
# #creacion de entorno virtual
# ![env1.jpg](attachment:env1.jpg)

# %% [markdown]
# #activacion del entorno virtual
# ![env2.jpg](attachment:env2.jpg)

# %% [markdown]
# #instalacion y comprobacion de paquetes
# ![env3.jpg](attachment:env3.jpg)

# %% [markdown]
# #desactivar el entorno
# ![env4.jpg](attachment:env4.jpg)
